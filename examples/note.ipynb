# %%
import pandas as pd

df = pd.read_csv("Books.csv")
print(df.columns)
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='str')
# C:\Users\Manswi R. dusane\AppData\Local\Temp\ipykernel_27968\1504209517.py:3: DtypeWarning: Columns (0: Year-Of-Publication) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Books.csv")

# %%
texts = df['Book-Author'].fillna("").tolist()

# %%
df.columns = df.columns.str.strip()
texts = df['Book-Author'].fillna("").tolist()

# %%
df = df.rename(columns={'Book-Author': 'author'})

# %%
print(df.columns)
# Out:
# Index(['ISBN', 'Book-Title', 'author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='str')

# %%
import pandas as pd

df = pd.read_csv('Books.csv')          # load CSV
df = df.rename(columns={'Book-Author': 'author'})  # rename column
# Out:
# C:\Users\Manswi R. dusane\AppData\Local\Temp\ipykernel_27968\1991105181.py:3: DtypeWarning: Columns (0: Year-Of-Publication) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Books.csv')          # load CSV
